# %% [markdown]
# <center><h1>1-cd: Convolutional Neural Networks (ConvNets)</h1></center>

# %%
import argparse
import os
import time

import torch
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim
import torch.utils.data
import torchvision.transforms as transforms
import torchvision.datasets as datasets

from utils import *

PRINT_INTERVAL = 200
PATH="datasets"

'''
IMPORTANT: to run torch on cuda (gpu), use this command instead to install it:
python -m pip install torch==2.2.0+cu118 torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
'''
# Out:
# '\nIMPORTANT: to run torch on cuda (gpu), use this command instead to install it:\npython -m pip install torch==2.2.0+cu118 torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118\n'

# %%
class ConvNet(nn.Module):
    """
    This class defines the structure of the neural network
    """

    def __init__(self, in_channels: int, in_features: int, out_features: int):
        super(ConvNet, self).__init__()
        # We first define the convolution and pooling layers as a features extractor
        self.features = nn.Sequential(
            nn.Conv2d(in_channels, 6, (5, 5), stride=1, padding=2), 
            nn.Tanh(),
            nn.MaxPool2d((2, 2), stride=2, padding=0),
            nn.Conv2d(6, 16, (5, 5), stride=1, padding=0),
            nn.Tanh(),
            nn.MaxPool2d((2, 2), stride=2, padding=0),
        )
        # We then define fully connected layers as a classifier
        self.classifier = nn.Sequential(
            nn.Linear(in_features, out_features),
            nn.Tanh(),
            nn.Linear(out_features, 84),
            nn.Tanh(),
            nn.Linear(84, 10)
            # Reminder: The softmax is included in the loss, do not put it here
        )

    # Method called when we apply the network to an input batch
    def forward(self, input):
        bsize = input.size(0) # batch size
        output = self.features(input) # output of the conv layers
        output = output.view(bsize, -1) # we flatten the 2D feature maps into one 1D vector for each input
        output = self.classifier(output) # we compute the output of the fc layers
        return output



def get_dataset(batch_size, dataset_name, cuda=False):
    """
    This function loads the dataset and performs transformations on each
    image (listed in `transform = ...`).
    """
    if dataset_name == 'CIFAR10':
        train_dataset = datasets.CIFAR10(PATH, train=True, download=True,
            transform=transforms.Compose([
                transforms.ToTensor()
            ]))
        
        val_dataset = datasets.CIFAR10(PATH, train=False, download=True,
            transform=transforms.Compose([
                transforms.ToTensor()
            ]))

    elif dataset_name == 'MNIST':
        train_dataset = datasets.MNIST(PATH, train=True, download=True,
            transform=transforms.Compose([
                transforms.ToTensor()
            ]))
        val_dataset = datasets.MNIST(PATH, train=False, download=True,
            transform=transforms.Compose([
                transforms.ToTensor()
            ]))
    
    else:
        return f'Dataset {dataset_name} name provided unknown...'

    train_loader = torch.utils.data.DataLoader(train_dataset,
                        batch_size=batch_size, shuffle=True, pin_memory=cuda, num_workers=2)
    val_loader = torch.utils.data.DataLoader(val_dataset,
                        batch_size=batch_size, shuffle=False, pin_memory=cuda, num_workers=2)

    return train_loader, val_loader



def epoch(data, model, criterion, optimizer=None, cuda=False):
    """
    Make a pass (called epoch in English) on the data `data` with the
     model `model`. Evaluates `criterion` as loss.
     If `optimizer` is given, perform a training epoch using
     the given optimizer, otherwise, perform an evaluation epoch (no backward)
     of the model.
    """

    # indicates whether the model is in eval or train mode (some layers behave differently in train and eval)
    model.eval() if optimizer is None else model.train()

    # objects to store metric averages
    avg_loss = AverageMeter()
    avg_top1_acc = AverageMeter()
    avg_top5_acc = AverageMeter()
    avg_batch_time = AverageMeter()
    global loss_plot

    # we iterate on the batches
    tic = time.time()
    for i, (input, target) in enumerate(data):

        if cuda: # only with GPU, and not with CPU
            input = input.cuda()
            target = target.cuda()

        # forward
        output = model(input)
        loss = criterion(output, target)

        # backward if we are training
        if optimizer:
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        # compute metrics
        prec1, prec5 = accuracy(output, target, topk=(1, 5))
        batch_time = time.time() - tic
        tic = time.time()

        # update
        avg_loss.update(loss.item())
        avg_top1_acc.update(prec1.item())
        avg_top5_acc.update(prec5.item())
        avg_batch_time.update(batch_time)
        if optimizer:
            loss_plot.update(avg_loss.val)
        # print info
        if i % PRINT_INTERVAL == 0:
            print('[{0:s} Batch {1:03d}/{2:03d}]\t'
                  'Time {batch_time.val:.3f}s ({batch_time.avg:.3f}s)\t'
                  'Loss {loss.val:.4f} ({loss.avg:.4f})\t'
                  'Prec@1 {top1.val:5.1f} ({top1.avg:5.1f})\t'
                  'Prec@5 {top5.val:5.1f} ({top5.avg:5.1f})'.format(
                   "EVAL" if optimizer is None else "TRAIN", i, len(data), batch_time=avg_batch_time, loss=avg_loss,
                   top1=avg_top1_acc, top5=avg_top5_acc))
            if optimizer:
                loss_plot.plot()

    # Print summary
    print('\n===============> Total time {batch_time:d}s\t'
          'Avg loss {loss.avg:.4f}\t'
          'Avg Prec@1 {top1.avg:5.2f} %\t'
          'Avg Prec@5 {top5.avg:5.2f} %\n'.format(
           batch_time=int(avg_batch_time.sum), loss=avg_loss,
           top1=avg_top1_acc, top5=avg_top5_acc))

    return avg_top1_acc, avg_top5_acc, avg_loss


def main(batch_size=128, lr=0.1, epochs=5, cuda=False, dataset_name='MNIST', in_channels=1, in_features=400, out_features=120):

    # ex :
    #   {"batch_size": 128, "epochs": 5, "lr": 0.1}

    # define model, loss, optim
    model = ConvNet(in_channels=in_channels, in_features=in_features, out_features=out_features)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr)

    if cuda: # only with GPU, and not with CPU
        cudnn.benchmark = True
        model = model.cuda()
        criterion = criterion.cuda()

    # Get the data
    train, test = get_dataset(batch_size, dataset_name, cuda)

    # init plots
    plot = AccLossPlot()
    global loss_plot
    loss_plot = TrainLossPlot()

    # We iterate on the epochs
    for i in range(epochs):
        print("=================\n=== EPOCH "+str(i+1)+" =====\n=================\n")
        # Train phase
        top1_acc, avg_top5_acc, loss = epoch(train, model, criterion, optimizer, cuda)
        # Test phase
        top1_acc_test, top5_acc_test, loss_test = epoch(test, model, criterion, cuda=cuda)
        # plot
        plot.update(loss.avg, loss_test.avg, top1_acc.avg, top1_acc_test.avg)

# %%
main(128, 0.1, cuda=False) # change cuda if its available
# Out:
# ...
# === EPOCH 1 =====
# ...
#
# [TRAIN Batch 000/469]	Time 6.462s (6.462s)	Loss 2.3027 (2.3027)	Prec@1  13.3 ( 13.3)	Prec@5  48.4 ( 48.4)
# [TRAIN Batch 200/469]	Time 0.018s (0.052s)	Loss 0.4245 (1.1868)	Prec@1  87.5 ( 65.2)	Prec@5  99.2 ( 91.9)
# [TRAIN Batch 400/469]	Time 0.025s (0.036s)	Loss 0.1862 (0.7367)	Prec@1  94.5 ( 78.6)	Prec@5 100.0 ( 95.7)
# ===============> Total time 15s	Avg loss 0.6570	Avg Prec@1 80.88 %	Avg Prec@5 96.34 %
#
# [EVAL Batch 000/079]	Time 9.382s (9.382s)	Loss 0.1148 (0.1148)	Prec@1  96.9 ( 96.9)	Prec@5 100.0 (100.0)
#
# ===============> Total time 10s	Avg loss 0.1645	Avg Prec@1 95.04 %	Avg Prec@5 99.86 %
# ...
# === EPOCH 2 =====
# ...
#
# [TRAIN Batch 000/469]	Time 5.912s (5.912s)	Loss 0.2374 (0.2374)	Prec@1  94.5 ( 94.5)	Prec@5 100.0 (100.0)
# [TRAIN Batch 200/469]	Time 0.018s (0.053s)	Loss 0.1733 (0.1503)	Prec@1  93.8 ( 95.6)	Prec@5 100.0 ( 99.9)
# [TRAIN Batch 400/469]	Time 0.013s (0.038s)	Loss 0.1283 (0.1324)	Prec@1  95.3 ( 96.1)	Prec@5 100.0 ( 99.9)
# ...

# %%
'''
here to get the in features and out features for CIFAR10
we need to calculate it ourselves
'''

main(batch_size=128, lr=0.1, epochs=10, cuda=False, dataset_name='CIFAR10', in_channels=3, in_features=576, out_features=128)
# Out:
# ...
# === EPOCH 1 =====
# ...
#
# [TRAIN Batch 000/391]	Time 16.690s (16.690s)	Loss 2.3056 (2.3056)	Prec@1   7.8 (  7.8)	Prec@5  48.4 ( 48.4)
# [TRAIN Batch 200/391]	Time 0.033s (0.122s)	Loss 2.0937 (2.1817)	Prec@1  25.8 ( 18.7)	Prec@5  71.1 ( 66.3)
# ===============> Total time 31s	Avg loss 2.0389	Avg Prec@1 25.11 %	Avg Prec@5 73.86 %
#
# [EVAL Batch 000/079]	Time 16.299s (16.299s)	Loss 1.8545 (1.8545)	Prec@1  34.4 ( 34.4)	Prec@5  82.0 ( 82.0)
#
# ===============> Total time 18s	Avg loss 1.8964	Avg Prec@1 31.18 %	Avg Prec@5 82.92 %
# ...
# === EPOCH 2 =====
# ...
#
# [TRAIN Batch 000/391]	Time 19.254s (19.254s)	Loss 1.8661 (1.8661)	Prec@1  35.2 ( 35.2)	Prec@5  78.9 ( 78.9)
# [TRAIN Batch 200/391]	Time 0.034s (0.134s)	Loss 1.7505 (1.6643)	Prec@1  35.2 ( 40.5)	Prec@5  88.3 ( 88.3)
# ===============> Total time 33s	Avg loss 1.6143	Avg Prec@1 42.25 %	Avg Prec@5 89.20 %
#
# [EVAL Batch 000/079]	Time 15.450s (15.450s)	Loss 1.4388 (1.4388)	Prec@1  51.6 ( 51.6)	Prec@5  91.4 ( 91.4)
#
# ...

# %%
import matplotlib.pyplot as plt

# Dummy class to satisfy loss_plot calls inside epoch()
class DummyLossPlot:
    def update(self, val):
        pass
    def plot(self):
        pass

def run_batchsize_experiments(batch_sizes=[16, 32, 64, 128], epochs=10, lr=0.1, dataset_name='MNIST', cuda=False):
    """
    Runs multiple experiments for different batch sizes using the existing ConvNet, get_dataset, and epoch functions.
    Produces a 2x2 multiplot of train/test accuracy and loss, one line per batch size.
    """

    # Store results
    results = {
        'train_acc': {},
        'test_acc': {},
        'train_loss': {},
        'test_loss': {}
    }

    global loss_plot  # required by your original epoch()
    loss_plot = DummyLossPlot()  # prevent NameError

    for bs in batch_sizes:
        print(f"\n===== Running experiment with batch size {bs} =====\n")

        # Initialize a fresh model
        model = ConvNet(
            in_channels=1 if dataset_name=='MNIST' else 3,
            in_features=400 if dataset_name=='MNIST' else 400,
            out_features=120
        )

        criterion = nn.CrossEntropyLoss()
        optimizer = torch.optim.SGD(model.parameters(), lr)

        # Load data
        train_loader, test_loader = get_dataset(bs, dataset_name, cuda)

        # Track per-epoch metrics
        train_accs, test_accs, train_losses, test_losses = [], [], [], []

        for epoch_idx in range(epochs):
            print(f"Epoch {epoch_idx+1}/{epochs} — Batch size {bs}")

            # Training
            top1_acc_train, _, loss_train = epoch(train_loader, model, criterion, optimizer, cuda)

            # Testing
            top1_acc_test, _, loss_test = epoch(test_loader, model, criterion, cuda=cuda)

            # Append metrics
            train_accs.append(top1_acc_train.avg)
            test_accs.append(top1_acc_test.avg)
            train_losses.append(loss_train.avg)
            test_losses.append(loss_test.avg)

        # Store results
        results['train_acc'][bs] = train_accs
        results['test_acc'][bs] = test_accs
        results['train_loss'][bs] = train_losses
        results['test_loss'][bs] = test_losses

    # --- Create multiplot ---
    fig, axs = plt.subplots(2, 2, figsize=(12, 10))
    fig.suptitle('ConvNet Performance Across Batch Sizes', fontsize=16)

    # Train Accuracy
    for bs in batch_sizes:
        axs[0, 0].plot(range(1, epochs+1), results['train_acc'][bs], label=f'BS={bs}')
    axs[0, 0].set_title('Train Accuracy')
    axs[0, 0].set_xlabel('Epoch')
    axs[0, 0].set_ylabel('Accuracy (%)')
    axs[0, 0].legend()
    axs[0, 0].grid(True)

    # Test Accuracy
    for bs in batch_sizes:
        axs[0, 1].plot(range(1, epochs+1), results['test_acc'][bs], label=f'BS={bs}')
    axs[0, 1].set_title('Test Accuracy')
    axs[0, 1].set_xlabel('Epoch')
    axs[0, 1].set_ylabel('Accuracy (%)')
    axs[0, 1].legend()
    axs[0, 1].grid(True)

    # Train Loss
    for bs in batch_sizes:
        axs[1, 0].plot(range(1, epochs+1), results['train_loss'][bs], label=f'BS={bs}')
    axs[1, 0].set_title('Train Loss')
    axs[1, 0].set_xlabel('Epoch')
    axs[1, 0].set_ylabel('Loss')
    axs[1, 0].legend()
    axs[1, 0].grid(True)

    # Test Loss
    for bs in batch_sizes:
        axs[1, 1].plot(range(1, epochs+1), results['test_loss'][bs], label=f'BS={bs}')
    axs[1, 1].set_title('Test Loss')
    axs[1, 1].set_xlabel('Epoch')
    axs[1, 1].set_ylabel('Loss')
    axs[1, 1].legend()
    axs[1, 1].grid(True)

    plt.tight_layout(rect=[0, 0, 1, 0.96])

    # Save figure
    plt.savefig("ConvNet_batchsize_multiplot.png", dpi=300)
    plt.show()

    return results

# %%
results = run_batchsize_experiments(
    batch_sizes=[16, 32, 64, 128],
    epochs=10,
    lr=0.1,
    dataset_name='MNIST',
    cuda=False
)
# Out:
# ===== Running experiment with batch size 16 =====
#
# Epoch 1/10 — Batch size 16
# [TRAIN Batch 000/3750]	Time 4.739s (4.739s)	Loss 2.2928 (2.2928)	Prec@1  12.5 ( 12.5)	Prec@5  62.5 ( 62.5)
# [TRAIN Batch 200/3750]	Time 0.000s (0.028s)	Loss 0.1577 (1.1379)	Prec@1 100.0 ( 65.7)	Prec@5 100.0 ( 91.3)
# [TRAIN Batch 400/3750]	Time 0.000s (0.017s)	Loss 0.1381 (0.7370)	Prec@1  93.8 ( 77.9)	Prec@5 100.0 ( 95.3)
# [TRAIN Batch 600/3750]	Time 0.000s (0.013s)	Loss 0.0337 (0.5687)	Prec@1 100.0 ( 82.8)	Prec@5 100.0 ( 96.8)
# [TRAIN Batch 800/3750]	Time 0.000s (0.011s)	Loss 0.1427 (0.4706)	Prec@1  93.8 ( 85.7)	Prec@5 100.0 ( 97.6)
# [TRAIN Batch 1000/3750]	Time 0.000s (0.010s)	Loss 0.0341 (0.4040)	Prec@1 100.0 ( 87.8)	Prec@5 100.0 ( 98.0)
# [TRAIN Batch 1200/3750]	Time 0.004s (0.009s)	Loss 0.0280 (0.3635)	Prec@1 100.0 ( 89.0)	Prec@5 100.0 ( 98.3)
# [TRAIN Batch 1400/3750]	Time 0.003s (0.008s)	Loss 0.4287 (0.3338)	Prec@1  87.5 ( 89.9)	Prec@5 100.0 ( 98.6)
# ...

# %%
def run_lr_experiments(learning_rates=[0.1, 0.01, 0.001, 0.0001], epochs=10, batch_size=32, dataset_name='MNIST', cuda=False):

    # Store results
    results = {
        'train_acc': {},
        'test_acc': {},
        'train_loss': {},
        'test_loss': {}
    }

    global loss_plot  # required by your original epoch()
    loss_plot = DummyLossPlot()  # prevent NameError

    for lr in learning_rates:
        print(f"\n===== Running experiment with learning rate {lr} =====\n")

        # Initialize a fresh model
        model = ConvNet(
            in_channels=1 if dataset_name=='MNIST' else 3,
            in_features=400 if dataset_name=='MNIST' else 400,
            out_features=120
        )

        criterion = nn.CrossEntropyLoss()
        optimizer = torch.optim.SGD(model.parameters(), lr)

        # Load data
        train_loader, test_loader = get_dataset(batch_size, dataset_name, cuda)

        # Track per-epoch metrics
        train_accs, test_accs, train_losses, test_losses = [], [], [], []

        for epoch_idx in range(epochs):
            print(f"Epoch {epoch_idx+1}/{epochs} — Learning rate {lr}")

            # Training
            top1_acc_train, _, loss_train = epoch(train_loader, model, criterion, optimizer, cuda)

            # Testing
            top1_acc_test, _, loss_test = epoch(test_loader, model, criterion, cuda=cuda)

            # Append metrics
            train_accs.append(top1_acc_train.avg)
            test_accs.append(top1_acc_test.avg)
            train_losses.append(loss_train.avg)
            test_losses.append(loss_test.avg)

        # Store results
        results['train_acc'][lr] = train_accs
        results['test_acc'][lr] = test_accs
        results['train_loss'][lr] = train_losses
        results['test_loss'][lr] = test_losses

    # --- Create multiplot ---
    fig, axs = plt.subplots(2, 2, figsize=(12, 10))
    fig.suptitle('ConvNet Performance Across Learning Rates', fontsize=16)

    # Train Accuracy
    for lr in learning_rates:
        axs[0, 0].plot(range(1, epochs+1), results['train_acc'][lr], label=f'LR={lr}')
    axs[0, 0].set_title('Train Accuracy')
    axs[0, 0].set_xlabel('Epoch')
    axs[0, 0].set_ylabel('Accuracy (%)')
    axs[0, 0].legend()
    axs[0, 0].grid(True)

    # Test Accuracy
    for lr in learning_rates:
        axs[0, 1].plot(range(1, epochs+1), results['test_acc'][lr], label=f'LR={lr}')
    axs[0, 1].set_title('Test Accuracy')
    axs[0, 1].set_xlabel('Epoch')
    axs[0, 1].set_ylabel('Accuracy (%)')
    axs[0, 1].legend()
    axs[0, 1].grid(True)

    # Train Loss
    for lr in learning_rates:
        axs[1, 0].plot(range(1, epochs+1), results['train_loss'][lr], label=f'LR={lr}')
    axs[1, 0].set_title('Train Loss')
    axs[1, 0].set_xlabel('Epoch')
    axs[1, 0].set_ylabel('Loss')
    axs[1, 0].legend()
    axs[1, 0].grid(True)

    # Test Loss
    for lr in learning_rates:
        axs[1, 1].plot(range(1, epochs+1), results['test_loss'][lr], label=f'LR={lr}')
    axs[1, 1].set_title('Test Loss')
    axs[1, 1].set_xlabel('Epoch')
    axs[1, 1].set_ylabel('Loss')
    axs[1, 1].legend()
    axs[1, 1].grid(True)

    plt.tight_layout(rect=[0, 0, 1, 0.96])

    # Save figure
    plt.savefig("ConvNet_lr_multiplot.png", dpi=300)
    plt.show()

    return results

# %%
results = run_lr_experiments(
    learning_rates=[0.1, 0.01, 0.001, 0.0001],
    epochs=10,
    batch_size=32,
    dataset_name='MNIST',
    cuda=False
)
# Out:
# ===== Running experiment with learning rate 0.1 =====
#
# Epoch 1/10 — Learning rate 0.1
# [TRAIN Batch 000/1875]	Time 5.311s (5.311s)	Loss 2.2916 (2.2916)	Prec@1  18.8 ( 18.8)	Prec@5  50.0 ( 50.0)
# [TRAIN Batch 200/1875]	Time 0.016s (0.033s)	Loss 0.2225 (1.0871)	Prec@1  93.8 ( 68.7)	Prec@5 100.0 ( 92.3)
# [TRAIN Batch 400/1875]	Time 0.016s (0.020s)	Loss 0.2392 (0.6693)	Prec@1  96.9 ( 80.8)	Prec@5 100.0 ( 96.0)
# [TRAIN Batch 600/1875]	Time 0.016s (0.016s)	Loss 0.1569 (0.5032)	Prec@1  96.9 ( 85.5)	Prec@5 100.0 ( 97.3)
# [TRAIN Batch 800/1875]	Time 0.037s (0.014s)	Loss 0.1316 (0.4104)	Prec@1  96.9 ( 88.1)	Prec@5 100.0 ( 97.9)
# [TRAIN Batch 1000/1875]	Time 0.002s (0.012s)	Loss 0.2841 (0.3518)	Prec@1  93.8 ( 89.8)	Prec@5 100.0 ( 98.3)
# [TRAIN Batch 1200/1875]	Time 0.005s (0.011s)	Loss 0.1043 (0.3119)	Prec@1  93.8 ( 90.9)	Prec@5 100.0 ( 98.6)
# [TRAIN Batch 1400/1875]	Time 0.000s (0.010s)	Loss 0.0356 (0.2810)	Prec@1 100.0 ( 91.8)	Prec@5 100.0 ( 98.8)
# ...

# %% [markdown]
# **For the CIFAR-10 dataset**
#
# This was run on gpu otherwise it would take a long time. Some code was reused from above.
#
# This outputs a multiplot like above for the accuracy in train/test, and the loss for train/test.

# %%
PATH = './data'  # CIFAR-10 data path

# ----------------- New ConvNet for CIFAR-10 -----------------
class ConvNet(nn.Module):
    def __init__(self, in_channels=3):
        super(ConvNet, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(in_channels, 32, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(32, 64, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(64, 64, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(2, 2)
        )
        self.classifier = nn.Sequential(
            nn.Linear(64*4*4, 1000),  
            nn.ReLU(),
            nn.Linear(1000, 10)
        )

    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x

def get_dataset(batch_size, cuda=True):
    transform = transforms.Compose([
        transforms.ToTensor(),
    ])
    train_dataset = datasets.CIFAR10(PATH, train=True, download=True, transform=transform)
    test_dataset = datasets.CIFAR10(PATH, train=False, download=True, transform=transform)

    train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2, pin_memory=cuda)
    test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=2, pin_memory=cuda)
    return train_loader, test_loader

def epoch(data, model, criterion, optimizer=None, cuda=True):
    model.train() if optimizer else model.eval()
    correct, total, running_loss = 0, 0, 0.0

    for inputs, targets in data:
        if cuda:
            inputs, targets = inputs.cuda(), targets.cuda()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        if optimizer:
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        running_loss += loss.item() * inputs.size(0)
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

    avg_loss = running_loss / total
    acc = 100. * correct / total
    return avg_loss, acc

def main(batch_size=128, lr=0.01, epochs=50, cuda=True):
    device = 'cuda' if cuda and torch.cuda.is_available() else 'cpu'
    print(f"Using device: {device}")

    model = ConvNet().to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=0.9)

    train_loader, test_loader = get_dataset(batch_size, cuda=(device=='cuda'))

    # Lists to store metrics
    train_losses, test_losses = [], []
    train_accs, test_accs = [], []

    for epoch_idx in range(1, epochs+1):
        train_loss, train_acc = epoch(train_loader, model, criterion, optimizer, cuda=(device=='cuda'))
        test_loss, test_acc = epoch(test_loader, model, criterion, optimizer=None, cuda=(device=='cuda'))

        train_losses.append(train_loss)
        test_losses.append(test_loss)
        train_accs.append(train_acc)
        test_accs.append(test_acc)

        print(f"Epoch {epoch_idx:02d}/{epochs} | "
              f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}% | "
              f"Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.2f}%")

    # ----------------- Plotting -----------------
    fig, axs = plt.subplots(2, 2, figsize=(12, 10))
    epochs_range = range(1, epochs+1)

    # Train Accuracy
    axs[0, 0].plot(epochs_range, train_accs, label='Train Acc')
    axs[0, 0].set_title('Train Accuracy')
    axs[0, 0].set_xlabel('Epoch')
    axs[0, 0].set_ylabel('Accuracy (%)')
    axs[0, 0].grid(True)

    # Test Accuracy
    axs[0, 1].plot(epochs_range, test_accs, label='Test Acc', color='orange')
    axs[0, 1].set_title('Test Accuracy')
    axs[0, 1].set_xlabel('Epoch')
    axs[0, 1].set_ylabel('Accuracy (%)')
    axs[0, 1].grid(True)

    # Train Loss
    axs[1, 0].plot(epochs_range, train_losses, label='Train Loss', color='green')
    axs[1, 0].set_title('Train Loss')
    axs[1, 0].set_xlabel('Epoch')
    axs[1, 0].set_ylabel('Loss')
    axs[1, 0].grid(True)

    # Test Loss
    axs[1, 1].plot(epochs_range, test_losses, label='Test Loss', color='red')
    axs[1, 1].set_title('Test Loss')
    axs[1, 1].set_xlabel('Epoch')
    axs[1, 1].set_ylabel('Loss')
    axs[1, 1].grid(True)

    plt.tight_layout()
    plt.show()

    return {
        'train_acc': train_accs,
        'test_acc': test_accs,
        'train_loss': train_losses,
        'test_loss': test_losses
    }

# %%
results = main(batch_size=128, lr=0.01, epochs=50, cuda=True)

# %% [markdown]
# Here is what we got on collab, and the graph is available on the report:
# ```
# Using device: cuda
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 01/50 | Train Loss: 1.8071, Train Acc: 33.23% | Test Loss: 1.4578, Test Acc: 47.99%
# Epoch 02/50 | Train Loss: 1.3066, Train Acc: 53.06% | Test Loss: 1.1695, Test Acc: 58.08%
# Epoch 03/50 | Train Loss: 1.0779, Train Acc: 61.45% | Test Loss: 1.0607, Test Acc: 61.64%
# Epoch 04/50 | Train Loss: 0.8944, Train Acc: 68.40% | Test Loss: 0.9059, Test Acc: 67.86%
# Epoch 05/50 | Train Loss: 0.7715, Train Acc: 73.07% | Test Loss: 0.8304, Test Acc: 70.85%
# Epoch 06/50 | Train Loss: 0.6610, Train Acc: 76.65% | Test Loss: 0.7957, Test Acc: 72.75%
# Epoch 07/50 | Train Loss: 0.5674, Train Acc: 80.07% | Test Loss: 0.7603, Test Acc: 73.85%
# Epoch 08/50 | Train Loss: 0.4854, Train Acc: 83.05% | Test Loss: 0.7749, Test Acc: 74.16%
# Epoch 09/50 | Train Loss: 0.3996, Train Acc: 86.04% | Test Loss: 0.7946, Test Acc: 74.52%
# Epoch 10/50 | Train Loss: 0.3165, Train Acc: 88.69% | Test Loss: 0.8337, Test Acc: 74.65%
# Epoch 11/50 | Train Loss: 0.2479, Train Acc: 91.27% | Test Loss: 0.8805, Test Acc: 74.89%
# Epoch 12/50 | Train Loss: 0.1808, Train Acc: 93.75% | Test Loss: 0.9720, Test Acc: 74.50%
# Epoch 13/50 | Train Loss: 0.1382, Train Acc: 95.21% | Test Loss: 1.0574, Test Acc: 74.50%
# Epoch 14/50 | Train Loss: 0.1000, Train Acc: 96.59% | Test Loss: 1.1417, Test Acc: 74.49%
# Epoch 15/50 | Train Loss: 0.0785, Train Acc: 97.33% | Test Loss: 1.2340, Test Acc: 75.25%
# Epoch 16/50 | Train Loss: 0.0643, Train Acc: 97.90% | Test Loss: 1.3987, Test Acc: 74.05%
# Epoch 17/50 | Train Loss: 0.0670, Train Acc: 97.69% | Test Loss: 1.3936, Test Acc: 74.09%
# Epoch 18/50 | Train Loss: 0.0499, Train Acc: 98.32% | Test Loss: 1.5266, Test Acc: 73.81%
# Epoch 19/50 | Train Loss: 0.0363, Train Acc: 98.84% | Test Loss: 1.5605, Test Acc: 73.91%
# Epoch 20/50 | Train Loss: 0.0312, Train Acc: 98.99% | Test Loss: 1.5680, Test Acc: 74.70%
# Epoch 21/50 | Train Loss: 0.0335, Train Acc: 98.90% | Test Loss: 1.5479, Test Acc: 74.91%
# Epoch 22/50 | Train Loss: 0.0309, Train Acc: 99.01% | Test Loss: 1.6002, Test Acc: 74.63%
# Epoch 23/50 | Train Loss: 0.0416, Train Acc: 98.63% | Test Loss: 1.5590, Test Acc: 74.72%
# Epoch 24/50 | Train Loss: 0.0289, Train Acc: 99.09% | Test Loss: 1.6203, Test Acc: 75.01%
# Epoch 25/50 | Train Loss: 0.0307, Train Acc: 98.99% | Test Loss: 1.6193, Test Acc: 74.85%
# Epoch 26/50 | Train Loss: 0.0247, Train Acc: 99.17% | Test Loss: 1.7017, Test Acc: 74.94%
# Epoch 27/50 | Train Loss: 0.0252, Train Acc: 99.17% | Test Loss: 1.7115, Test Acc: 74.83%
# Epoch 28/50 | Train Loss: 0.0212, Train Acc: 99.30% | Test Loss: 1.6902, Test Acc: 75.34%
# Epoch 29/50 | Train Loss: 0.0062, Train Acc: 99.81% | Test Loss: 1.8064, Test Acc: 76.08%
# Epoch 30/50 | Train Loss: 0.0015, Train Acc: 99.97% | Test Loss: 1.7749, Test Acc: 76.32%
# Epoch 31/50 | Train Loss: 0.0002, Train Acc: 100.00% | Test Loss: 1.8127, Test Acc: 76.68%
# Epoch 32/50 | Train Loss: 0.0001, Train Acc: 100.00% | Test Loss: 1.8397, Test Acc: 76.70%
# Epoch 33/50 | Train Loss: 0.0001, Train Acc: 100.00% | Test Loss: 1.8633, Test Acc: 76.73%
# Epoch 34/50 | Train Loss: 0.0001, Train Acc: 100.00% | Test Loss: 1.8825, Test Acc: 76.68%
# Epoch 35/50 | Train Loss: 0.0001, Train Acc: 100.00% | Test Loss: 1.8980, Test Acc: 76.76%
# Epoch 36/50 | Train Loss: 0.0001, Train Acc: 100.00% | Test Loss: 1.9119, Test Acc: 76.69%
# Epoch 37/50 | Train Loss: 0.0001, Train Acc: 100.00% | Test Loss: 1.9246, Test Acc: 76.72%
# Epoch 38/50 | Train Loss: 0.0001, Train Acc: 100.00% | Test Loss: 1.9361, Test Acc: 76.74%
# Epoch 39/50 | Train Loss: 0.0001, Train Acc: 100.00% | Test Loss: 1.9468, Test Acc: 76.77%
# Epoch 40/50 | Train Loss: 0.0001, Train Acc: 100.00% | Test Loss: 1.9571, Test Acc: 76.77%
# Epoch 41/50 | Train Loss: 0.0001, Train Acc: 100.00% | Test Loss: 1.9666, Test Acc: 76.78%
# Epoch 42/50 | Train Loss: 0.0001, Train Acc: 100.00% | Test Loss: 1.9757, Test Acc: 76.81%
# Epoch 43/50 | Train Loss: 0.0000, Train Acc: 100.00% | Test Loss: 1.9840, Test Acc: 76.81%
# Epoch 44/50 | Train Loss: 0.0000, Train Acc: 100.00% | Test Loss: 1.9915, Test Acc: 76.82%
# Epoch 45/50 | Train Loss: 0.0000, Train Acc: 100.00% | Test Loss: 1.9990, Test Acc: 76.82%
# Epoch 46/50 | Train Loss: 0.0000, Train Acc: 100.00% | Test Loss: 2.0064, Test Acc: 76.83%
# Epoch 47/50 | Train Loss: 0.0000, Train Acc: 100.00% | Test Loss: 2.0131, Test Acc: 76.81%
# Epoch 48/50 | Train Loss: 0.0000, Train Acc: 100.00% | Test Loss: 2.0193, Test Acc: 76.84%
# Epoch 49/50 | Train Loss: 0.0000, Train Acc: 100.00% | Test Loss: 2.0257, Test Acc: 76.84%
# Epoch 50/50 | Train Loss: 0.0000, Train Acc: 100.00% | Test Loss: 2.0318, Test Acc: 76.83%
# ```

# %% [markdown]
# code to test other normalization tecnhiques

# %%
from sklearn.decomposition import PCA
import torch.nn.functional as F

# %%
class ZCAWhitening:
    """Applies ZCA whitening to a batch of images (expects tensor CxHxW)"""
    def __init__(self, dataset):
        # Flatten images and compute covariance
        X = torch.stack([transforms.ToTensor()(img) for img, _ in dataset]).view(len(dataset), -1)
        X = X - X.mean(0, keepdim=True)
        sigma = X.T @ X / len(dataset)
        U, S, _ = torch.svd(sigma)
        self.ZCA_matrix = U @ torch.diag(1.0 / torch.sqrt(S + 1e-5)) @ U.T

        self.mean = X.mean(0)

    def __call__(self, img):
        x = img.view(-1) - self.mean
        x = self.ZCA_matrix @ x
        return x.view(3, 32, 32)

class LpNormalize:
    """Normalizes a tensor by its Lp norm (p=1 or p=2)"""
    def __init__(self, p=2):
        self.p = p

    def __call__(self, x):
        # x = transforms.ToTensor()(x)
        norm = torch.norm(x.flatten(), p=self.p)
        return x / (norm + 1e-7)


# ----------------- Get dataset -----------------
def get_dataset(batch_size, cuda=True, normalization='standard'):
    cifar_mean = (0.491, 0.482, 0.447)
    cifar_std  = (0.202, 0.199, 0.201)

    transforms_list = []

    # Standard ToTensor first
    transforms_list.append(transforms.ToTensor())

    if normalization == 'standard':
        transforms_list.append(transforms.Normalize(cifar_mean, cifar_std))
    elif normalization == 'minmax':
        transforms_list.append(transforms.Lambda(lambda x: x*2 - 1))
    elif normalization == 'per_image':
        transforms_list.append(LpNormalize(p=2))  # per-image L2 norm
    elif normalization == 'l1':
        transforms_list.append(LpNormalize(p=1))
    elif normalization == 'zca':
        # Use ZCA whitening from the training dataset
        train_dataset_tmp = datasets.CIFAR10(PATH, train=True, download=True)
        zca = ZCAWhitening(train_dataset_tmp)
        transforms_list.append(zca)
    else:
        raise ValueError(f"Unknown normalization: {normalization}")

    transform = transforms.Compose(transforms_list)

    train_dataset = datasets.CIFAR10(PATH, train=True, download=True, transform=transform)
    test_dataset = datasets.CIFAR10(PATH, train=False, download=True, transform=transform)

    train_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=batch_size, shuffle=True, num_workers=2, pin_memory=cuda
    )
    test_loader = torch.utils.data.DataLoader(
        test_dataset, batch_size=batch_size, shuffle=False, num_workers=2, pin_memory=cuda
    )

    return train_loader, test_loader

# %%
def epoch(data, model, criterion, optimizer=None, cuda=True):
    model.train() if optimizer else model.eval()
    correct, total, running_loss = 0, 0, 0.0

    for inputs, targets in data:
        if cuda:
            inputs, targets = inputs.cuda(), targets.cuda()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        if optimizer:
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        running_loss += loss.item() * inputs.size(0)
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

    avg_loss = running_loss / total
    acc = 100. * correct / total
    return avg_loss, acc


# ----------------- Multi-normalization training & plotting -----------------
def train_multiple_normalizations(batch_size=128, lr=0.01, epochs=50, cuda=True):
    device = 'cuda' if cuda and torch.cuda.is_available() else 'cpu'
    print(f"Using device: {device}")

    normalizations = ['zca', 'per_image', 'standard', 'minmax']  # add 'zca' if implemented
    all_results = {}

    colors = ['blue', 'orange', 'green', 'red', 'purple']

    for idx, norm in enumerate(normalizations):
        print(f"\n=== Training with normalization: {norm} ===\n")

        model = ConvNet().to(device)
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.SGD(model.parameters(), lr=lr, momentum=0.9)

        train_loader, test_loader = get_dataset(batch_size, cuda=(device=='cuda'), normalization=norm)

        train_losses, test_losses = [], []
        train_accs, test_accs = [], []

        for epoch_idx in range(1, epochs+1):
            train_loss, train_acc = epoch(train_loader, model, criterion, optimizer, cuda=(device=='cuda'))
            test_loss, test_acc = epoch(test_loader, model, criterion, optimizer=None, cuda=(device=='cuda'))

            train_losses.append(train_loss)
            test_losses.append(test_loss)
            train_accs.append(train_acc)
            test_accs.append(test_acc)

            print(f"Epoch {epoch_idx:02d}/{epochs} | "
                  f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}% | "
                  f"Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.2f}%")

        all_results[norm] = {
            'train_loss': train_losses,
            'test_loss': test_losses,
            'train_acc': train_accs,
            'test_acc': test_accs,
            'color': colors[idx % len(colors)]
        }

    # ----------------- Plotting -----------------
    fig, axs = plt.subplots(2, 2, figsize=(12, 10))
    epochs_range = range(1, epochs+1)

    for norm, res in all_results.items():
        axs[0, 0].plot(epochs_range, res['train_acc'], label=norm, color=res['color'])
        axs[0, 1].plot(epochs_range, res['test_acc'], label=norm, color=res['color'])
        axs[1, 0].plot(epochs_range, res['train_loss'], label=norm, color=res['color'])
        axs[1, 1].plot(epochs_range, res['test_loss'], label=norm, color=res['color'])

    axs[0, 0].set_title('Train Accuracy')
    axs[0, 0].set_xlabel('Epoch'); axs[0, 0].set_ylabel('Accuracy (%)'); axs[0, 0].grid(True); axs[0, 0].legend()
    axs[0, 1].set_title('Test Accuracy')
    axs[0, 1].set_xlabel('Epoch'); axs[0, 1].set_ylabel('Accuracy (%)'); axs[0, 1].grid(True); axs[0, 1].legend()
    axs[1, 0].set_title('Train Loss')
    axs[1, 0].set_xlabel('Epoch'); axs[1, 0].set_ylabel('Loss'); axs[1, 0].grid(True); axs[1, 0].legend()
    axs[1, 1].set_title('Test Loss')
    axs[1, 1].set_xlabel('Epoch'); axs[1, 1].set_ylabel('Loss'); axs[1, 1].grid(True); axs[1, 1].legend()

    plt.tight_layout()
    plt.show()

    return all_results

# %%
results = train_multiple_normalizations(batch_size=128, lr=0.01, epochs=50, cuda=True)
